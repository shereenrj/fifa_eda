# %%
# Load the necessary libraries (numpy and pandas,matplotlib)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import and Load the Dataset with the name "fifa"

# %%
df=pd.read_csv('fifa.csv')
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#            Value    Wage Preferred Foot  International Reputation  ...  \
# ...

# %% [markdown]
# ## Q8: Which players have the highest wages based upon nationality. Mention the Player who has the highest wage amongst all nationalities & how much?

# %%
mp = df.groupby(['Nationality'],as_index=False).agg(lambda x: x.max() if x.dtype=='int64' else x.head(1))
mp
# Out:
#      Nationality      ID          Name  Age  Overall  Potential     Value  \
# 0    Afghanistan  244175       H. Amin   26       63         71    450000
# 1        Albania  245792  T. Strakosha   34       81         86  20000000
# 2        Algeria  245565     R. Mahrez   35       85         85  40500000
# 3        Andorra  192937    Marc Vales   28       62         64    290000
# 4         Angola  242188        Bastos   34       78         82  10000000
# ..           ...     ...           ...  ...      ...        ...       ...
# 159   Uzbekistan  197597   O. Akhmedov   30       75         75   6000000
# 160    Venezuela  246388   J. Martínez   34       81         84  22500000
# 161        Wales  246227       G. Bale   37       88         88  60000000
# 162       Zambia  246144      S. Sunzu   29       73         83   3500000
# 163     Zimbabwe  239438    M. Nakamba   34       78         83  12000000
#
#        Wage Preferred Foot  International Reputation  ...  Penalties  \
# ...

# %%
mp.sort_values(by='Wage',ascending=False)
# Out:
#     Nationality      ID               Name  Age  Overall  Potential  \
# 6     Argentina  246609           L. Messi   41       94         94
# 158     Uruguay  246387          L. Suárez   37       91         91
# 35      Croatia  245275          L. Modrić   38       91         91
# 123    Portugal  246603  Cristiano Ronaldo   37       94         94
# 139       Spain  246617             De Gea   39       91         93
# ..          ...     ...                ...  ...      ...        ...
# 74    Indonesia  244623   E. Maulana Vikri   17       56         74
# 111   Nicaragua  244740          L. Copete   29       66         66
# 125       Qatar  245688          A. Yasser   24       63         68
# 82       Jordan  226139          J. Tamimi   23       63         70
# 73        India  245170         S. Chhetri   33       67         71
#
#          Value    Wage Preferred Foot  International Reputation  ...  \
# 6    110500000  565000           Left                       5.0  ...
# ...

# %%
df.sort_values(by='Wage',ascending=False)
# Out:
#            ID               Name  Age  Nationality  Overall  Potential  \
# 0      158023           L. Messi   31    Argentina       94         94
# 7      176580          L. Suárez   31      Uruguay       91         91
# 6      177003          L. Modrić   32      Croatia       91         91
# 1       20801  Cristiano Ronaldo   33     Portugal       94         94
# 8      155862       Sergio Ramos   32        Spain       91         91
# ...       ...                ...  ...          ...      ...        ...
# 5614   175608           A. Fathi   33        Egypt       70         70
# 14786  233524           U. Singh   22        India       60         67
# 3170   221422         S. Ingason   24      Iceland       73         78
# 5595   201714            D. Böde   31      Hungary       70         70
# 12684  208543        C. Howieson   23  New Zealand       63         68
#
#            Value    Wage Preferred Foot  International Reputation  ...  \
# ...

# %%
df['Value']
# Out:
# 0        110500000
# 1         77000000
# 2        118500000
# 3         72000000
# 4        102000000
#            ...
# 18202        60000
# 18203        60000
# 18204        60000
# 18205        60000
# 18206        60000
# Name: Value, Length: 18207, dtype: int64

# %%
mean = df['Value'].mean()
mean
# Out:
# 2410695.8861976163

# %%
L = df[(df['Value']<mean)]
L
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 318      5479            Casillas   37       Spain       82         82
# 452    207439          L. Paredes   24   Argentina       80         85
# 538    156713        A. Granqvist   33      Sweden       80         80
# 544    146748         Diego López   36       Spain       80         80
# 549    139997             D. Srna   36     Croatia       80         80
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#          Value   Wage Preferred Foot  International Reputation  ...  \
# ...

# %%
M = df[(df['Value']==mean)]
M
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Nationality, Overall, Potential, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes]
# Index: []
#
# [0 rows x 54 columns]

# %%
H = df[(df['Value']>mean)]
H
# Out:
#           ID               Name  Age Nationality  Overall  Potential  \
# 0     158023           L. Messi   31   Argentina       94         94
# 1      20801  Cristiano Ronaldo   33    Portugal       94         94
# 2     190871          Neymar Jr   26      Brazil       92         93
# 3     193080             De Gea   27       Spain       91         93
# 4     192985       K. De Bruyne   27     Belgium       91         92
# ...      ...                ...  ...         ...      ...        ...
# 5611  219127        P. Galdames   21       Chile       70         80
# 5613  238072           E. Löwen   21     Germany       70         80
# 5622  225530          O. Oularé   22     Belgium       70         77
# 5627  237819       N. Domínguez   20   Argentina       70         82
# 5636  231423        C. De Norre   21     Belgium       70         79
#
#           Value    Wage Preferred Foot  International Reputation  ...  \
# ...

# %%
H.groupby('Nationality')['Value']

# %% [markdown]
# ## Q10: Create a new dataframe to further analyze the 8 High Valued Nationality
# hint: use describe()

# %%
H.describe().T
# Out:
#                            count          mean           std        min  \
# ID                        4015.0  2.049036e+05  2.537007e+04       41.0
# Age                       4015.0  2.618630e+01  3.653143e+00       17.0
# Overall                   4015.0  7.529738e+01  3.778988e+00       70.0
# Potential                 4015.0  7.826027e+01  4.343354e+00       71.0
# Value                     4015.0  8.668867e+06  9.524293e+06  2500000.0
# Wage                      4015.0  3.093499e+04  3.934717e+04     1000.0
# International Reputation  4015.0  1.425156e+00  6.950711e-01        1.0
# Weak Foot                 4015.0  3.151183e+00  7.120627e-01        1.0
# Skill Moves               4015.0  2.859527e+00  8.320278e-01        1.0
# Jersey Number             4015.0  1.650162e+01  1.466266e+01        1.0
# Contract Valid Until      4015.0  2.020639e+03  1.361077e+00     2018.0
# Height                    4015.0  5.808767e+00  4.460273e-01        5.1
# ...

# %% [markdown]
# ## Q11. Display the distribution of the International Reputation of the Nationality Argentina. Comment on how the distribution looks like and interpret some insights from the plot.

# %%
df1 = df['Nationality']== 'Argentina'

# %%
df1
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
sns.countplot(data=df1, x='Nationality')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.countplot(data=df1, x='Nationality')
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
df.groupby('Nationality')['International Reputation'].plot(kind='bar')
plt.show()

# %%
df.groupby('Nationality')['International Reputation'].plot(kind='bar')
plt.show()

# %% [markdown]
# ## Q12. Display the distribution of the players based upon the Age in denmark. Comment on how the distribution looks like and interpret some insights from the plot.

# %%
fifa_d = df[df['Nationality']=='Denmark']

# %%
fifa_d
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 31     190460         C. Eriksen   26     Denmark       88         91
# 149    163587      K. Schmeichel   31     Denmark       84         84
# 278    193283         T. Delaney   26     Denmark       82         83
# 336    213661     A. Christensen   22     Denmark       81         88
# 387    179645            S. Kjær   29     Denmark       81         81
# ...       ...                ...  ...         ...      ...        ...
# 18116  243709       K. Moesgaard   21     Denmark       50         61
# 18133  246142     M. Finne Wørts   19     Denmark       49         61
# 18153  246270         M. Dyrmose   17     Denmark       49         69
# 18162  243866       T. Gundelund   16     Denmark       48         66
# 18164  243876  M. Frøkjær-Jensen   18     Denmark       48         63
#
#           Value    Wage Preferred Foot  International Reputation  ...  \
# ...

# %%
sns.displot(data=fifa_d, x='Age',kde=True)
plt.show()
